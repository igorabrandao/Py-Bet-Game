# %% [markdown]
# # Programming Project - Unit 1,1
# *by Igor A. Brandão -> 2014041985*
#
# **Goals**
# - Reinforce and practice main ideas and skills presented in the first
# lessons about Python;
#     - Loop, random, numpy, list, functions, so on...
#
# **IMD Bet Game**
#
# In the IMD bet game, your next move depends on the number of eyes you throw with the dice.
#
# **Rules**
#
# *Input:*
# - Floor "f", where step = max(0,f);
# - Epoch (roll) = 100;
# - Seed;
# - Number of rounds = **500**.
#
# *For each rounds*
#
# *For each epoch (roll):*
#
# - Roll the dice;
# - Determine the next step;
#
# | Case | Whats happen |
# | --- | --- |
# | `Case 1,2:` | Decrease step by one |
# | `Case 3,4,5:` | Increase step by one |
# | `Case 6:` | Roll de dice again and move accordling to result of the new dice |
#
# - There is a 0,1% probability that assign the step to 0 (zero) in each step;
# - Store the current step
#
# Round[i] = steps

# %% [markdown]
# Code starts here!!!
# ==============================

# %% [markdown]
# ## Data structure
#
# Here is the section that I defined the data structure

# %%
# Import the math package
import math

# Import the random package
import random

# Import the numpy package
import numpy as np

# Seed for random number generation
seed = 1
np.random.seed(seed)

##################### Program settings #####################

# You can change these parameters to simulate new results
min_floor = 0
max_floor = 100
epoch = 10
n_rounds = 50
step = 0
diceFace = 1

############################################################

# Auxiliary variables
current_floor = np.random.randint(min_floor, max_floor)
aux_floor = current_floor
current_round = 0
current_epoch = 0
aux_step = step
assign_zero = 0

# Create the program data structure
build = np.array(np.random.randint(1, 20))
rounds = [None] * n_rounds

# %% [markdown]
# ## Print settings function
#
# This function print the used parameters to run the current simulation

# %%
# Function to print settings
def printSettings():
    print('##################### Program settings #####################')
    print('min_floor \t= ', min_floor)
    print('max_floor \t= ', max_floor)
    print('epoch \t\t= ', epoch)
    print('n_rounds \t= ', n_rounds)
    print('step \t\t= ', step)
    print('diceFace \t= ', diceFace)
    print('\nStarting floor \t= ', current_floor)
    print('############################################################\n')

# %% [markdown]
# ## Roll dices function
#
# This function determines what does mean rolling dices

# %%
# Roll dices function
def rollDice():
    return np.random.randint(1, 7)

# %% [markdown]
# ## Cases mapping
#
# As python doesn't have *switch/case* structure, so I'm going to map the behavior
# accordling to the dice face

# %%
# Define the function blocks
def case12():
    global step
    step -= 1

def case345():
    global step
    step += 1

def case6():
    global step
    diceFace = rollDice()
    step += diceFace
    # print ('New Dice face: ', diceFace)

# Map the dice face to the function blocks
nextStep = {1 : case12,
            2 : case12,
            3 : case345,
            4 : case345,
            5 : case345,
            6 : case6,}

# %% [markdown]
# ## Iterations
#
# Ok, now that we have the necessary info's, let's roll some dices!

# %%
# Print the current settings
printSettings()

# For each rounds
for current_round in range(current_round, n_rounds): 
    print ('\n### ROUND[', current_round, '] ###\n')
    
    # For each epoch (roll)
    for current_epoch in range(current_epoch, epoch):
        # Roll the dice
        diceFace = rollDice()
        
        # Determine the next step
        nextStep[diceFace]()
        aux_step += step

        # Change the current floor
        aux_floor = current_floor + step 
        if ( aux_floor >= min_floor and aux_floor <= max_floor ):
            current_floor += step

        # Probability to step to 0 floor
        assign_zero = (0, current_floor)[random.uniform(0, 1) < 0.1]
        
        # Check if it's necessary stepping to 0 floor
        if ( assign_zero != 0 ):
            current_floor = 0

        # Print a rolling log
        print ('Dice[', current_epoch,'] face: ', diceFace, '\tSTEP: ', step, '\tFLOOR: ', current_floor, 
               '\tASSIGN_ZERO: ', assign_zero)
        
        # Increase the epoc iterator
        current_epoch += 1
        
        # Renew step result
        step = 0
    
    # Renew the epoc iterator
    current_epoch = 0
    
     # Add the step in the current round
    rounds[current_round] = aux_step
    
    # Renew tha aux_step variable
    aux_step = 0
    
    # Increase the round iterator
    current_round += 1
# Out:
# ##################### Program settings #####################
# min_floor 	=  0
# max_floor 	=  100
# epoch 		=  10
# n_rounds 	=  50
# step 		=  0
# diceFace 	=  1
#
# Starting floor 	=  37
# ############################################################
#
#
# ### ROUND[ 0 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  38 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  37
# Dice[ 2 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  6 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  2
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  5 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
#
# ### ROUND[ 1 ] ###
#
# Dice[ 0 ] face:  3 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  6 	STEP:  3 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  5 	STEP:  1 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  3 	STEP:  1 	FLOOR:  14 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  15 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  3 	FLOOR:  18 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  5 	STEP:  1 	FLOOR:  19 	ASSIGN_ZERO:  0
#
# ### ROUND[ 2 ] ###
#
# Dice[ 0 ] face:  2 	STEP:  -1 	FLOOR:  18 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  2 	STEP:  -1 	FLOOR:  17 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  1 	STEP:  -1 	FLOOR:  16 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  6 	STEP:  2 	FLOOR:  18 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  2 	STEP:  -1 	FLOOR:  17 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  2 	FLOOR:  19 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  2 	STEP:  -1 	FLOOR:  18 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  1 	STEP:  -1 	FLOOR:  17 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  5 	STEP:  1 	FLOOR:  18 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  17 	ASSIGN_ZERO:  0
#
# ### ROUND[ 3 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  16 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  15
# Dice[ 2 ] face:  6 	STEP:  4 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  2 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  4 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  2 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  6
#
# ### ROUND[ 4 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  2
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  1 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  4 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  4
#
# ### ROUND[ 5 ] ###
#
# Dice[ 0 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  1
# Dice[ 3 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  2
# Dice[ 6 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
#
# ### ROUND[ 6 ] ###
#
# Dice[ 0 ] face:  6 	STEP:  5 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  7
# Dice[ 2 ] face:  6 	STEP:  2 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  4 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  1 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  3 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  3 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
#
# ### ROUND[ 7 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  3 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  1 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  2 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  2 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  6 	STEP:  4 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  4
# Dice[ 8 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  6 	STEP:  6 	FLOOR:  6 	ASSIGN_ZERO:  0
#
# ### ROUND[ 8 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  3 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  5 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  4 	STEP:  1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  6 	STEP:  4 	FLOOR:  16 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  1 	FLOOR:  17 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  4 	STEP:  1 	FLOOR:  18 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  19 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  4 	STEP:  1 	FLOOR:  20 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  5 	STEP:  1 	FLOOR:  21 	ASSIGN_ZERO:  0
#
# ### ROUND[ 9 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  22 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  5 	FLOOR:  27 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  26
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  1 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  3 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  5 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
#
# ### ROUND[ 10 ] ###
#
# Dice[ 0 ] face:  2 	STEP:  -1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  2 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  5 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
#
# ### ROUND[ 11 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  3
# Dice[ 1 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  2 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  2
# Dice[ 5 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  3 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  3 	ASSIGN_ZERO:  0
#
# ### ROUND[ 12 ] ###
#
# Dice[ 0 ] face:  2 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  3 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  6 	STEP:  2 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  6
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  6 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
#
# ### ROUND[ 13 ] ###
#
# Dice[ 0 ] face:  3 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  5
# Dice[ 2 ] face:  6 	STEP:  5 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  1 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  2 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
#
# ### ROUND[ 14 ] ###
#
# Dice[ 0 ] face:  2 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  2 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  6 	STEP:  5 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  12
# Dice[ 6 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
#
# ### ROUND[ 15 ] ###
#
# Dice[ 0 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  6 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  5 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  6 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  6 	STEP:  1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  4 	FLOOR:  14 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  2 	STEP:  -1 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  2 	STEP:  -1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  1 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  6 	STEP:  1 	FLOOR:  14 	ASSIGN_ZERO:  0
#
# ### ROUND[ 16 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  15 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  3 	STEP:  1 	FLOOR:  16 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  6 	STEP:  4 	FLOOR:  20 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  21 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  22 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  21 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  6 	STEP:  4 	FLOOR:  25 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  4 	STEP:  1 	FLOOR:  26 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  6 	FLOOR:  32 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  31 	ASSIGN_ZERO:  0
#
# ### ROUND[ 17 ] ###
#
# Dice[ 0 ] face:  3 	STEP:  1 	FLOOR:  32 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  33 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  34
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  5 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  3 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  7 	ASSIGN_ZERO:  0
#
# ### ROUND[ 18 ] ###
#
# Dice[ 0 ] face:  6 	STEP:  4 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  1 	STEP:  -1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  6 	STEP:  3 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  2 	STEP:  -1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  1 	STEP:  -1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  4 	STEP:  1 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  12 	ASSIGN_ZERO:  0
#
# ### ROUND[ 19 ] ###
#
# Dice[ 0 ] face:  2 	STEP:  -1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  3 	STEP:  1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  5 	STEP:  1 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  14 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  15 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  4 	STEP:  1 	FLOOR:  16 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  4 	STEP:  1 	FLOOR:  17 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  4 	STEP:  1 	FLOOR:  18 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  19 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  20 	ASSIGN_ZERO:  0
#
# ### ROUND[ 20 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  21 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  5 	FLOOR:  26 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  27 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  28 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  29 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  5 	STEP:  1 	FLOOR:  30 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  1 	STEP:  -1 	FLOOR:  29 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  30
# Dice[ 8 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
#
# ### ROUND[ 21 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  6 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  2 	STEP:  -1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  3 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  1 	STEP:  -1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  7 	ASSIGN_ZERO:  0
#
# ### ROUND[ 22 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  5 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  2 	STEP:  -1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  4 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  2 	STEP:  -1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  3 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
#
# ### ROUND[ 23 ] ###
#
# Dice[ 0 ] face:  6 	STEP:  2 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  1 	STEP:  -1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  10
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
#
# ### ROUND[ 24 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  3
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  2
# Dice[ 6 ] face:  6 	STEP:  5 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  4 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  1 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
#
# ### ROUND[ 25 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  6 	STEP:  2 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  6 	STEP:  5 	FLOOR:  0 	ASSIGN_ZERO:  11
# Dice[ 4 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  6 	STEP:  3 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  5 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  4 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  5 	STEP:  1 	FLOOR:  14 	ASSIGN_ZERO:  0
#
# ### ROUND[ 26 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  15 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  14 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  15 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  16 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  17 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  4 	FLOOR:  21 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  22 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  3 	STEP:  1 	FLOOR:  23 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  4 	STEP:  1 	FLOOR:  24 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  23 	ASSIGN_ZERO:  0
#
# ### ROUND[ 27 ] ###
#
# Dice[ 0 ] face:  6 	STEP:  6 	FLOOR:  29 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  3 	STEP:  1 	FLOOR:  30 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  2 	STEP:  -1 	FLOOR:  29 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  4 	STEP:  1 	FLOOR:  30 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  31
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  6 	STEP:  2 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  3
#
# ### ROUND[ 28 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  5 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  1 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  3 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  5 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  4
#
# ### ROUND[ 29 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  4 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  1 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  6 	STEP:  6 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  3 	STEP:  1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  3 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
#
# ### ROUND[ 30 ] ###
#
# Dice[ 0 ] face:  6 	STEP:  2 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  2 	STEP:  -1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  2 	STEP:  -1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  6 	STEP:  6 	FLOOR:  16 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  5 	STEP:  1 	FLOOR:  17 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  18 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  3 	STEP:  1 	FLOOR:  19 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  20
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
#
# ### ROUND[ 31 ] ###
#
# Dice[ 0 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  1
# Dice[ 2 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  2 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  4 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
#
# ### ROUND[ 32 ] ###
#
# Dice[ 0 ] face:  2 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  3 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  6 	STEP:  6 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  9
# Dice[ 4 ] face:  6 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  1
# Dice[ 5 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
#
# ### ROUND[ 33 ] ###
#
# Dice[ 0 ] face:  6 	STEP:  2 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  2 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  5
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
#
# ### ROUND[ 34 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  3 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  5
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  1
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  3 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  3 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  1 	STEP:  -1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  6 	STEP:  3 	FLOOR:  0 	ASSIGN_ZERO:  5
#
# ### ROUND[ 35 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  1
# Dice[ 2 ] face:  6 	STEP:  2 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  6 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  4 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  1 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  4 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  7
#
# ### ROUND[ 36 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
#
# ### ROUND[ 37 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  5 	FLOOR:  0 	ASSIGN_ZERO:  9
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  6 	STEP:  4 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  4 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  10 	ASSIGN_ZERO:  0
#
# ### ROUND[ 38 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  1 	STEP:  -1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  1 	STEP:  -1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  2 	STEP:  -1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  3 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  8 	ASSIGN_ZERO:  0
#
# ### ROUND[ 39 ] ###
#
# Dice[ 0 ] face:  3 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  10
# Dice[ 2 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  6 	STEP:  2 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  2 	FLOOR:  0 	ASSIGN_ZERO:  5
# Dice[ 6 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
#
# ### ROUND[ 40 ] ###
#
# Dice[ 0 ] face:  3 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  2 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  4
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  4 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  2 	STEP:  -1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  5 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
#
# ### ROUND[ 41 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  4 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  3 	STEP:  1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  5 	STEP:  1 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  12
#
# ### ROUND[ 42 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  5 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  4 	STEP:  1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  1 	STEP:  -1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  5 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  11
#
# ### ROUND[ 43 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  1
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  4 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  5 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  3
# Dice[ 6 ] face:  6 	STEP:  4 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  2 	FLOOR:  0 	ASSIGN_ZERO:  6
# Dice[ 8 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  5 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
#
# ### ROUND[ 44 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  3 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  3 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  3 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  3 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  1 	STEP:  -1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  3 	STEP:  1 	FLOOR:  8 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  2 	STEP:  -1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  6 	STEP:  3 	FLOOR:  10 	ASSIGN_ZERO:  0
#
# ### ROUND[ 45 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  6 	STEP:  1 	FLOOR:  12 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  1 	STEP:  -1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  6 	STEP:  6 	FLOOR:  0 	ASSIGN_ZERO:  17
# Dice[ 4 ] face:  6 	STEP:  2 	FLOOR:  0 	ASSIGN_ZERO:  2
# Dice[ 5 ] face:  2 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  4 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  2
# Dice[ 8 ] face:  6 	STEP:  4 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  2 	STEP:  -1 	FLOOR:  3 	ASSIGN_ZERO:  0
#
# ### ROUND[ 46 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  4 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  2 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  1 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  6 	FLOOR:  13 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  3 	STEP:  1 	FLOOR:  14 	ASSIGN_ZERO:  0
#
# ### ROUND[ 47 ] ###
#
# Dice[ 0 ] face:  5 	STEP:  1 	FLOOR:  15 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  16 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  17
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  0 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  6 	STEP:  3 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  6 	STEP:  1 	FLOOR:  0 	ASSIGN_ZERO:  6
# Dice[ 8 ] face:  5 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  6 	STEP:  3 	FLOOR:  0 	ASSIGN_ZERO:  4
#
# ### ROUND[ 48 ] ###
#
# Dice[ 0 ] face:  4 	STEP:  1 	FLOOR:  1 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  2 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  3 	STEP:  1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  5 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  2 	STEP:  -1 	FLOOR:  3 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  4 	STEP:  1 	FLOOR:  4 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  4 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  1 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 9 ] face:  4 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
#
# ### ROUND[ 49 ] ###
#
# Dice[ 0 ] face:  1 	STEP:  -1 	FLOOR:  5 	ASSIGN_ZERO:  0
# Dice[ 1 ] face:  5 	STEP:  1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 2 ] face:  4 	STEP:  1 	FLOOR:  7 	ASSIGN_ZERO:  0
# Dice[ 3 ] face:  1 	STEP:  -1 	FLOOR:  6 	ASSIGN_ZERO:  0
# Dice[ 4 ] face:  6 	STEP:  4 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 5 ] face:  2 	STEP:  -1 	FLOOR:  9 	ASSIGN_ZERO:  0
# Dice[ 6 ] face:  5 	STEP:  1 	FLOOR:  10 	ASSIGN_ZERO:  0
# Dice[ 7 ] face:  5 	STEP:  1 	FLOOR:  11 	ASSIGN_ZERO:  0
# Dice[ 8 ] face:  6 	STEP:  3 	FLOOR:  0 	ASSIGN_ZERO:  14
# Dice[ 9 ] face:  6 	STEP:  6 	FLOOR:  6 	ASSIGN_ZERO:  0

# %% [markdown]
# ## Debug
#
# Good way to visualize internal processing...

# %%
# Print round array
for i in [rounds]:
    print(i)
# Out:
# [4, 14, -2, 4, 5, 0, 9, 6, 15, 8, 0, 4, 8, 6, 6, 14, 17, 8, 5, 8, 10, 7, 2, -1, 8, 20, 9, 10, 4, 11, 10, 0, 11, 1, 10, 7, 2, 16, -2, 6, 8, 6, 10, 12, 8, 13, 11, 12, 6, 14]
